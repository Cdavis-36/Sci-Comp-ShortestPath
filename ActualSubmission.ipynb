# %% [markdown]
# # Actual Submission File for Stage 2

# %%
using Revise
includet("../Sci-Comp-ShortestPath/WeightedGraphs.jl")
using .WeightedGraphs

# %% [markdown]
# ### All of part 1 and part 2c is included in the "WeightedGraphs.jl" module and in the "Testing.jl" file.

# %% [markdown]
# ### Part 2a)

# %%
v1 = Vertex(:A)
v2 = Vertex(:B)
v3 = Vertex(:C)
v4 = Vertex(:D)
v5 = Vertex(:E)
v6 = Vertex(:F)
v7 = Vertex(:G)
v8 = Vertex(:H)
E1 = WeightedGraphs.Edge(:A,:B,9)
E2 = WeightedGraphs.Edge(:A,:C,12)
E3 = WeightedGraphs.Edge(:A,:D,15)
E4 = WeightedGraphs.Edge(:A,:E,8)
E5 = WeightedGraphs.Edge(:A,:F,20)
E6 = WeightedGraphs.Edge(:B,:C,24)
E7 = WeightedGraphs.Edge(:B,:D,2)
E8 = WeightedGraphs.Edge(:B,:E,4)
E9 = WeightedGraphs.Edge(:B,:F,10)
E10 = WeightedGraphs.Edge(:C,:D,15)
E11 = WeightedGraphs.Edge(:C,:E,12)
E12 = WeightedGraphs.Edge(:C,:F,7)
E13 = WeightedGraphs.Edge(:D,:E,16)
E14 = WeightedGraphs.Edge(:D,:F,18)
E15 = WeightedGraphs.Edge(:E,:F,22)
g = WeightedGraph()
addVertices!(g,v1,v2,v3,v4,v5,v6)
addEdges!(g,E1,E2,E3,E4,E5,E6,E7,E8,E9,E10,E11,E12,E13,E14,E15)
plotWeightedGraph(g)

# %% [markdown]
# ### Part 2b)

# %%
P = Path([Vertex(:C), Vertex(:A), Vertex(:F), Vertex(:B)],g)
distance(P)
# Out:
# 42

# %% [markdown]
# ### Part 2d)

# %%
solveTSP(g)
# Out:
# 7-element Vector{Vertex}:
#  D
#  B
#  E
#  A
#  C
#  F
#  D

# %% [markdown]
# ### Part 3a)

# %%
e1 = WeightedGraphs.Edge(:A,:B,9)
e2 = WeightedGraphs.Edge(:A,:D,13)
e3 = WeightedGraphs.Edge(:A,:E,16)
e4 = WeightedGraphs.Edge(:B,:C,15)
e5 = WeightedGraphs.Edge(:B,:E,3)
e6 = WeightedGraphs.Edge(:C,:E,10)
e7 = WeightedGraphs.Edge(:C,:F,4)
e8 = WeightedGraphs.Edge(:D,:E,18)
e9 = WeightedGraphs.Edge(:E,:F,17)
e10 = WeightedGraphs.Edge(:E,:G,21)
e11 = WeightedGraphs.Edge(:F,:G,12)
e12 = WeightedGraphs.Edge(:F,:H,24)
e13 = WeightedGraphs.Edge(:G,:H,5)
g2 = WeightedGraph()
addVertices!(g2,v1,v2,v3,v4,v5,v6,v7,v8)
addEdges!(g2,e1,e2,e3,e4,e5,e6,e7,e8,e9,e10,e11,e12,e13)
plotWeightedGraph(g2)

# %% [markdown]
# ### Part 3b)

# %%
findShortestPath(Vertex(:C), Vertex(:D), g2)
# Out:
# (Path = Vertex[C, E, D], Distance = 28)

# %% [markdown]
# ### Part 3c)

# %%
findShortestPath(Vertex(:A), Vertex(:H), g2)
# Out:
# (Path = Vertex[A, B, E, G, H], Distance = 38)

# %% [markdown]
# ### Part 4a)

# %%
map = WeightedGraph()
V1 = Vertex(:PJ)
V2 = Vertex(:NMF)
V3 = Vertex(:JL)
V4 = Vertex(:WM)
V5 = Vertex(:EM)
V6 = Vertex(:EW)
V7 = Vertex(:WS)
V8 = Vertex(:SL)
V9 = Vertex(:SW)
V10 = Vertex(:WB)
V11 = Vertex(:SJ)
V12 = Vertex(:NML)
V13 = Vertex(:MP)
V14 = Vertex(:NR2)
V15 = Vertex(:MR2)
V16 = Vertex(:HC)
V17 = Vertex(:FSU)
V18 = Vertex(:Cinema)
addVertices!(map,V1,V2,V3,V4,V5,V6,V7,V8,V9,V10,V11,V12,V13,V14,V15,V16,V17,V18)
E_1 = WeightedGraphs.Edge(:FSU,:MP,4266)#.24)
E_2 = WeightedGraphs.Edge(:FSU,:NMF,2476)#.32)
E_3 = WeightedGraphs.Edge(:FSU,:PJ,1826)#.88)
E_4 = WeightedGraphs.Edge(:MP,:SL,3009)#.6)
E_5 = WeightedGraphs.Edge(:NMF,:SL,1278)
E_6 = WeightedGraphs.Edge(:NMF,:JL,4239)#.84)
E_7 = WeightedGraphs.Edge(:PJ,:JL,1647)#.36)
E_8 = WeightedGraphs.Edge(:PJ,:WM,5966)#.4)
E_9 = WeightedGraphs.Edge(:SL,:SW,8500)#.8)
E_10 = WeightedGraphs.Edge(:JL,:SJ,5074)#.08)
E_11 = WeightedGraphs.Edge(:JL,:WM,5179)#.68)
E_12 = WeightedGraphs.Edge(:WM,:EM,1174)
E_13 = WeightedGraphs.Edge(:SW,:MR2,3791)#.04)
E_14 = WeightedGraphs.Edge(:SW,:WB,2972)#.64)
E_15 = WeightedGraphs.Edge(:SJ,:WB,2983)#.2)
E_16 = WeightedGraphs.Edge(:EM,:EW,6652)#.8)
E_17 = WeightedGraphs.Edge(:MR2,:WB,5232)#.48)
E_18 = WeightedGraphs.Edge(:WB,:WS,4039)#.2)
E_19 = WeightedGraphs.Edge(:SJ,:WS,3405)#.6)
E_20 = WeightedGraphs.Edge(:EW,:WS,5596)#.8)
E_21 = WeightedGraphs.Edge(:MR2,:NR2,5649)#.6)
E_22 = WeightedGraphs.Edge(:WS,:NML,8342)#.4)
E_23 = WeightedGraphs.Edge(:EW,:NML,3907)#.2)
E_24 = WeightedGraphs.Edge(:NR2,:HC,5702)#.4)
E_25 = WeightedGraphs.Edge(:NR2,:Cinema,6441)#.6)
E_26 = WeightedGraphs.Edge(:NML,:Cinema,12619)#.2)
E_27 = WeightedGraphs.Edge(:HC,:Cinema,1705)#.44)
addEdges!(map,E_1,E_2,E_3,E_4,E_5,E_6,E_7,E_8,E_9,E_10,E_11,E_12,E_13,E_14,E_15,E_16,E_17,E_18,E_19,E_20,E_21,E_22,E_23,E_24,E_25,E_26,E_27)
plotWeightedGraph(map)

# %% [markdown]
# ### Part 4b)

# %%
findShortestPath(Vertex(:FSU), Vertex(:Cinema), map)
# Out:
# (Path = Vertex[FSU, PJ, JL, SJ, WB, MR2, NR2, Cinema], Distance = 28852)

# %% [markdown]
# The given path is:
#
# FSU -> intersection of Pearl St & John Fitch Hwy
#
# -> intersection of John Fitch Hwy & Lunenburg St
#
# -> intersection of Summer St & John Fitch Hwy
#
# -> intersection of Water St & Bemis Rd
#
# -> intersection of Merriam Ave & Rt2
#
# -> intersection of North Main St & Rt2
#
# -> Cinema.
#
# This gives a total minimum distance of about $28,852$ ft or about 5.46mi. This is only slightly higher than what Google Maps gives as the shortest distance between the two addresses as it gives 5.4 miles.

# %% [markdown]
# ### Testing

# %%
using Revise
include("Testing.jl")
# Out:
# Test Summary: | Pass  Total  Time
# Vertex        |    3      3  0.0s
# Test Summary: | Pass  Total  Time
# Edge          |    2      2  0.0s
# Test Summary:  | Pass  Total  Time
# Weighted Graph |    1      1  0.0s
# Test Summary: | Pass  Total  Time
# Add Vertex    |    2      2  0.0s
# Test Summary:          | Pass  Total  Time
# Add Vector of Vertices |    3      3  0.0s
# Test Summary: | Pass  Total  Time
# Add Vertices  |    3      3  0.0s
# Test Summary:              | Pass  Total  Time
# This vertex already exists |    3      3  0.0s
# Test Summary: | Pass  Total  Time
# Add edge      |    2      2  0.0s
# Test Summary:       | Pass  Total  Time
# Add vector of edges |    3      3  0.0s
# Test Summary: | Pass  Total  Time
# Add edges     |    3      3  0.0s
# Test Summary:       | Pass  Total  Time
# Plot Weighted Graph |    1      1  0.2s
# Test Summary: | Pass  Total  Time
# Path          |    2      2  0.0s
# Test Summary:                  | Pass  Total  Time
# ...
